# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv('C:/Users/lode/Downloads/archive (1)/bestsellers with categories.csv')

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
book = df.copy()

# %%
book
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
book.sample(10)
# Out:
#                                                   Name                 Author  \
# 416  The Instant Pot Electric Pressure Cooker Cookb...        Laurel Randolph
# 311                                StrengthsFinder 2.0                 Gallup
# 461  The Short Second Life of Bree Tanner: An Eclip...        Stephenie Meyer
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)            Jeff Kinney
# 404                                           The Help       Kathryn Stockett
# 262    P is for Potty! (Sesame Street) (Lift-the-Flap)        Naomi Kleinberg
# 240  National Geographic Little Kids First Big Book...            Amy Shields
# 320  The 5 Love Languages: The Secret to Love That ...           Gary Chapman
# 169              How to Win Friends & Influence People          Dale Carnegie
# 486                   The Wonderful Things You Will Be  Emily Winfield Martin
#
#      User Rating  Reviews  Price  Year        Genre
# 416          4.3     7368      7  2018  Non Fiction
# ...

# %%
book.isnull().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
bar = book['Author'].value_counts().sort_values(ascending = False).head(5)

# %%
plt.figure(figsize = (10, 6))
sns.barplot(x = bar, y = bar.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
plt.xlabel('Counts', fontsize = 15)
plt.ylabel('Author', fontsize = 15)
plt.title('Top 5 Authors with Most Books (2009 -2019)', fontsize = 20, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Top 5 Authors with Most Books (2009 -2019)')

# %%
pie = book['Genre'].value_counts()
labels = ['Non Fiction', 'Fiction']

# %%
plt.figure(figsize = (10, 6))
plt.pie(pie, autopct = '%0.f%%', shadow = True, colors = ['#577399', '#BDD5EA'])
plt.legend(labels = labels, bbox_to_anchor = (0,1), fontsize = 15)
plt.title('Genres Percantage (2009 - 2019)', fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Genres Percantage (2009 - 2019)')

# %%
book['Year'].value_counts().sort_index()
# Out:
# 2009    50
# 2010    50
# 2011    50
# 2012    50
# 2013    50
# 2014    50
# 2015    50
# 2016    50
# 2017    50
# 2018    50
# 2019    50
# Name: Year, dtype: int64

# %%
plt.figure(figsize = (10, 8))
sns.countplot(x = 'Year', data = book, hue = 'Genre', palette= ['#577399', '#BDD5EA'])
plt.title('Count of Each Genres Each Year (2009 - 2019)', fontsize = 17, fontweight = 'bold')
plt.xlabel('Year', fontsize = 17)
plt.ylabel('Count', fontsize = 17)
# Out:
# Text(0, 0.5, 'Count')

# %%
line = book[['Year', 'Genre']].value_counts().sort_index().reset_index()
line.columns = ['Year', 'Genre', 'Counts']

# %%
line
# Out:
#     Year        Genre  Counts
# 0   2009      Fiction      24
# 1   2009  Non Fiction      26
# 2   2010      Fiction      20
# 3   2010  Non Fiction      30
# 4   2011      Fiction      21
# 5   2011  Non Fiction      29
# 6   2012      Fiction      21
# 7   2012  Non Fiction      29
# 8   2013      Fiction      24
# 9   2013  Non Fiction      26
# 10  2014      Fiction      29
# 11  2014  Non Fiction      21
# 12  2015      Fiction      17
# 13  2015  Non Fiction      33
# 14  2016      Fiction      19
# 15  2016  Non Fiction      31
# 16  2017      Fiction      24
# 17  2017  Non Fiction      26
# 18  2018      Fiction      21
# 19  2018  Non Fiction      29
# 20  2019      Fiction      20
# 21  2019  Non Fiction      30

# %%
plt.figure(figsize = (15, 8))
sns.lineplot(data = line, x = 'Year', y = 'Counts', hue = 'Genre', palette = ['#577399', '#BDD5EA'], linewidth = 4)
plt.title('Genres Fluctuation in Year to Year', fontsize = 15, fontweight = 'bold')
plt.xticks(np.arange(2008, 2020, 2))
plt.legend(fontsize = 15)
plt.xlabel('Year', fontsize = 17)
plt.ylabel('Count', fontsize = 17)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (12, 6))
sns.countplot(x = 'Year', data = book, color = '#577399')
plt.title('Total of Best Sellers Books Each Year (2009 - 2019)', fontsize = 15, fontweight = 'bold')
plt.xlabel('Year', fontsize = 17)
plt.ylabel('Count', fontsize = 17)
# Out:
# Text(0, 0.5, 'Count')

# %%
price_max = {'2009' : book[book['Year'] == 2009]['Price'].max(),
            '2010' : book[book['Year'] == 2010]['Price'].max(),
            '2011' : book[book['Year'] == 2011]['Price'].max(),
            '2012' : book[book['Year'] == 2012]['Price'].max(),
            '2013' : book[book['Year'] == 2013]['Price'].max(),
            '2014' : book[book['Year'] == 2014]['Price'].max(),
            '2015' : book[book['Year'] == 2015]['Price'].max(),
            '2016' : book[book['Year'] == 2016]['Price'].max(),
            '2017' : book[book['Year'] == 2017]['Price'].max(),
            '2018' : book[book['Year'] == 2018]['Price'].max(),
            '2019' : book[book['Year'] == 2019]['Price'].max()}

# %%
price_max = pd.Series(price_max)

# %%
price_max
# Out:
# 2009     82
# 2010     46
# 2011     46
# 2012     46
# 2013    105
# 2014    105
# 2015     46
# 2016     54
# 2017     46
# 2018     46
# 2019     27
# dtype: int64

# %%
sns.lineplot(data = price_max)
# Out:
# <AxesSubplot:>

# %%
price_mean = {'2009' : book[book['Year'] == 2009]['Price'].mean(),
            '2010' : book[book['Year'] == 2010]['Price'].mean(),
            '2011' : book[book['Year'] == 2011]['Price'].mean(),
            '2012' : book[book['Year'] == 2012]['Price'].mean(),
            '2013' : book[book['Year'] == 2013]['Price'].mean(),
            '2014' : book[book['Year'] == 2014]['Price'].mean(),
            '2015' : book[book['Year'] == 2015]['Price'].mean(),
            '2016' : book[book['Year'] == 2016]['Price'].mean(),
            '2017' : book[book['Year'] == 2017]['Price'].mean(),
            '2018' : book[book['Year'] == 2018]['Price'].mean(),
            '2019' : book[book['Year'] == 2019]['Price'].mean()}

# %%
price_mean = pd.Series(price_mean)

# %%
price_mean
# Out:
# 2009    15.40
# 2010    13.48
# 2011    15.10
# 2012    15.30
# 2013    14.60
# 2014    14.64
# 2015    10.42
# 2016    13.18
# 2017    11.38
# 2018    10.52
# 2019    10.08
# dtype: float64

# %%
sns.lineplot(data = price_mean)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (12, 6))
sns.lineplot(data = price_max, label = 'Max Price', linewidth = 5, color = '#BDD5EA')

sns.lineplot(data = price_mean, label = 'Average Price', linewidth = 5, color = '#577399')
plt.legend()
plt.title('Highest and Average Price of Best Sellers Books Each Year (2009 - 2019)', fontsize = 15, fontweight = 'bold')
plt.xlabel('Year', fontsize = 17)
plt.ylabel('Price', fontsize = 17)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.figure(figsize = (12, 6))
sns.histplot(x = 'Reviews', data = book, binwidth = 1500, hue = 'Genre', palette = ['#495867', '#FE5F55'], kde = True)
plt.title('Distribution of Reviews Per Genres', fontsize = 15, fontweight = 'bold')
plt.xlabel('Reviews', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
# Out:
# Text(0, 0.5, 'Count')

# %%
book.sort_values(by = 'Reviews', ascending = False)
# Out:
#                                                   Name             Author  \
# 534                            Where the Crawdads Sing        Delia Owens
# 382                              The Girl on the Train      Paula Hawkins
# 383                              The Girl on the Train      Paula Hawkins
# 32                                            Becoming     Michelle Obama
# 33                                            Becoming     Michelle Obama
# ..                                                 ...                ...
# 359  The Daily Show with Jon Stewart Presents Earth...        Jon Stewart
# 512                             True Compass: A Memoir  Edward M. Kennedy
# 121                    George Washington's Sacred Fire  Peter A. Lillback
# 300  Soul Healing Miracles: Ancient and New Sacred ...       Zhi Gang Sha
# 78   Divine Soul Mind Body Healing and Transmission...       Zhi Gang Sha
#
#      User Rating  Reviews  Price  Year        Genre
# ...

# %%
plt.figure(figsize = (12, 6))
sns.histplot(x = 'User Rating', data = book, binwidth = 0.11, hue = 'Genre', kde = True, palette = ['#495867', '#FE5F55'])
plt.title('Distribution of Ratings Per Genres', fontsize = 15, fontweight = 'bold')
plt.xlabel('User Rating', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (12, 6))
sns.scatterplot(x = 'User Rating', y = 'Price', data = book)
# Out:
# <AxesSubplot:xlabel='User Rating', ylabel='Price'>

# %%
plt.figure(figsize = (12, 6))
sns.scatterplot(x = 'Reviews', y = 'Price', data = book)
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Price'>

# %%
sns.scatterplot(x = 'Reviews', y = 'User Rating', data = book)
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='User Rating'>

# %%
index_names = book[(book['Price'] > 60) | (book['Reviews'] > 60000)].index
book_drop = book.drop(index_names)

# %%
book_drop['Price'].sort_values(ascending = False)
# Out:
# 151    54
# 346    53
# 159    52
# 275    46
# 272    46
#        ..
# 116     0
# 71      0
# 505     0
# 508     0
# 358     0
# Name: Price, Length: 542, dtype: int64

# %%
plt.figure(figsize = (12, 6))
sns.regplot(x = 'Reviews', y = 'Price', data = book_drop)
# Out:
# <AxesSubplot:xlabel='Reviews', ylabel='Price'>

# %%
book.sort_values(by = 'User Rating', ascending = False).head(5)
# Out:
#                                                   Name       Author  \
# 431                                 The Magnolia Story  Chip Gaines
# 87   Dog Man: Lord of the Fleas: From the Creator o...   Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...   Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...   Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...   Dav Pilkey
#
#      User Rating  Reviews  Price  Year        Genre
# 431          4.9     7861      5  2016  Non Fiction
# 87           4.9     5470      6  2018      Fiction
# 85           4.9    12619      8  2019      Fiction
# 84           4.9     7235      4  2019      Fiction
# 83           4.9     7235      4  2018      Fiction

# %%
print('Top 5 Authors with Highest Score User Rating :')
book.sort_values(by = 'User Rating', ascending = False).head(5)
# Out:
# Top 5 Authors with Highest Score User Rating :
#                                                   Name       Author  \
# 431                                 The Magnolia Story  Chip Gaines
# 87   Dog Man: Lord of the Fleas: From the Creator o...   Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...   Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...   Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...   Dav Pilkey
#
#      User Rating  Reviews  Price  Year        Genre
# 431          4.9     7861      5  2016  Non Fiction
# 87           4.9     5470      6  2018      Fiction
# 85           4.9    12619      8  2019      Fiction
# 84           4.9     7235      4  2019      Fiction
# 83           4.9     7235      4  2018      Fiction

# %%
print('Top 5 Authors with Most Reviews :')
book.sort_values(by = 'Reviews', ascending = False).head(5)
# Out:
# Top 5 Authors with Most Reviews :
#                         Name          Author  User Rating  Reviews  Price  \
# 534  Where the Crawdads Sing     Delia Owens          4.8    87841     15
# 382    The Girl on the Train   Paula Hawkins          4.1    79446     18
# 383    The Girl on the Train   Paula Hawkins          4.1    79446      7
# 32                  Becoming  Michelle Obama          4.8    61133     11
# 33                  Becoming  Michelle Obama          4.8    61133     11
#
#      Year        Genre
# 534  2019      Fiction
# 382  2015      Fiction
# 383  2016      Fiction
# 32   2018  Non Fiction
# 33   2019  Non Fiction

# %%
year_2009 = book[book['Year'] == 2009]

# %%
year_2009_chart = year_2009['Author'].value_counts().sort_values(ascending = False).head(5)
year_2009_chart
# Out:
# Stephenie Meyer     6
# Charlaine Harris    2
# Jeff Kinney         2
# Glenn Beck          2
# David Zinczenko     2
# Name: Author, dtype: int64

# %%
year_2010 = book[book['Year'] == 2010]
year_2010_chart = year_2010['Author'].value_counts().sort_values(ascending = False).head(5)
year_2010_chart
# Out:
# Rick Riordan       4
# Suzanne Collins    3
# Stieg Larsson      3
# David Platt        1
# Tony Hsieh         1
# Name: Author, dtype: int64

# %%
year_2011 = book[book['Year'] == 2011]
year_2011_chart = year_2011['Author'].value_counts().sort_values(ascending = False).head(5)
year_2011_chart
# Out:
# Suzanne Collins                       4
# Rick Riordan                          2
# Kathryn Stockett                      2
# David Platt                           1
# American Psychological Association    1
# Name: Author, dtype: int64

# %%
year_2012 = book[book['Year'] == 2012]
year_2012_chart = year_2012['Author'].value_counts().sort_values(ascending = False).head(5)
year_2012_chart
# Out:
# Suzanne Collins    4
# E L James          4
# Rick Riordan       2
# Bill O'Reilly      2
# Mark Owen          1
# Name: Author, dtype: int64

# %%
year_2013 = book[book['Year'] == 2013]
year_2013_chart = year_2013['Author'].value_counts().sort_values(ascending = False).head(5)
year_2013_chart
# Out:
# Veronica Roth                         2
# Rob Elliott                           2
# Stephen King                          2
# American Psychological Association    1
# Gillian Flynn                         1
# Name: Author, dtype: int64

# %%
year_2014 = book[book['Year'] == 2014]
year_2014_chart = year_2014['Author'].value_counts().sort_values(ascending = False).head(5)
year_2014_chart
# Out:
# John Green           3
# Veronica Roth        2
# RH Disney            2
# Rob Elliott          2
# Laura Hillenbrand    2
# Name: Author, dtype: int64

# %%
year_2015 = book[book['Year'] == 2015]
year_2015_chart = year_2015['Author'].value_counts().sort_values(ascending = False).head(5)
year_2012_chart
# Out:
# Suzanne Collins    4
# E L James          4
# Rick Riordan       2
# Bill O'Reilly      2
# Mark Owen          1
# Name: Author, dtype: int64

# %%
year_2016 = book[book['Year'] == 2016]
year_2016_chart = year_2016['Author'].value_counts().sort_values(ascending = False).head(5)
year_2016_chart
# Out:
# J.K. Rowling                   4
# Ray Bradbury                   1
# Carol S. Dweck                 1
# Adult Coloring Book Designs    1
# Ron Chernow                    1
# Name: Author, dtype: int64

# %%
year_2017 = book[book['Year'] == 2017]
year_2017_chart = year_2017['Author'].value_counts().sort_values(ascending = False).head(5)
year_2017_chart
# Out:
# Rupi Kaur              2
# Wizards RPG Team       1
# J. D. Vance            1
# Fredrik Backman        1
# Neil deGrasse Tyson    1
# Name: Author, dtype: int64

# %%
year_2018 = book[book['Year'] == 2018]
year_2018_chart = year_2018['Author'].value_counts().sort_values(ascending = False).head(5)
year_2018_chart
# Out:
# Dav Pilkey                3
# Joanna Gaines             2
# Dr. Steven R Gundry MD    2
# Celeste Ng                1
# Bob Woodward              1
# Name: Author, dtype: int64

# %%
year_2019 = book[book['Year'] == 2019]
year_2019_chart = year_2019['Author'].value_counts().sort_values(ascending = False).head(5)
year_2019_chart
# Out:
# Dav Pilkey          3
# Rachel Hollis       2
# Wizards RPG Team    1
# Naomi Kleinberg     1
# School Zone         1
# Name: Author, dtype: int64

# %%
fig, axes = plt.subplots(6, 2, figsize = (20, 30), squeeze = True)
fig.suptitle('Top 5 Authors with Most Books Each Year (2009 - 2019)', fontsize = 25, fontweight = 'bold')
plt.subplots_adjust(hspace= 0.4)
sns.barplot(ax = axes[0, 0], x = year_2009_chart, y = year_2009_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[0, 1], x = year_2010_chart, y = year_2010_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[1, 0], x = year_2011_chart, y = year_2011_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[1, 1], x = year_2012_chart, y = year_2012_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[2, 0], x = year_2013_chart, y = year_2013_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[2, 1], x = year_2014_chart, y = year_2014_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[3, 0], x = year_2015_chart, y = year_2015_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[3, 1], x = year_2016_chart, y = year_2016_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[4, 0], x = year_2017_chart, y = year_2017_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[4, 1], x = year_2018_chart, y = year_2018_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
sns.barplot(ax = axes[5, 0], x = year_2019_chart, y = year_2019_chart.index, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
axes[0,0].set_title('Year 2009', fontsize = 17)
axes[0,1].set_title('Year 2010', fontsize = 17)
axes[1,0].set_title('Year 2011', fontsize = 17)
axes[1,1].set_title('Year 2012', fontsize = 17)
axes[2,0].set_title('Year 2013', fontsize = 17)
axes[2,1].set_title('Year 2014', fontsize = 17)
axes[3,0].set_title('Year 2015', fontsize = 17)
axes[3,1].set_title('Year 2016', fontsize = 17)
axes[4,0].set_title('Year 2017', fontsize = 17)
axes[4,1].set_title('Year 2018', fontsize = 17)
axes[5,0].set_title('Year 2019', fontsize = 17)
# Out:
# Text(0.5, 1.0, 'Year 2019')

# %%
high_price = book[['Price', 'Author']].sort_values(by = 'Price', ascending = False).head(6)

# %%
high_price
# Out:
#      Price                            Author
# 69     105  American Psychiatric Association
# 70     105  American Psychiatric Association
# 473     82                   Stephenie Meyer
# 151     54                Lin-Manuel Miranda
# 346     53                      Bill Simmons
# 159     52                     J. K. Rowling

# %%
plt.figure(figsize = (12, 6))
sns.barplot(x = 'Price', y = 'Author', data = high_price, palette = ['#495867', '#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
plt.title('Top 5 Authors With Most Expensive Books (2009 - 2019)', fontsize = 15, fontweight = 'bold')
plt.ylabel('Author', fontsize = 15)
plt.xlabel('Price', fontsize = 15)
# Out:
# Text(0.5, 0, 'Price')

# %%
genre_rating = book.groupby('Genre')['User Rating'].mean().reset_index()
genre_rating
# Out:
#          Genre  User Rating
# 0      Fiction     4.648333
# 1  Non Fiction     4.595161

# %%
plt.figure(figsize = (10, 6))
ax = sns.barplot(x = 'Genre', y = 'User Rating', data = genre_rating, palette = ['#577399', '#BDD5EA'])
ax.bar_label(ax.containers[0], fontsize = 15)
plt.title('Average Rating for Each Genres', fontsize = 15, fontweight = 'bold')
plt.xlabel('Genre', fontsize = 15)
plt.ylabel('User Rating', fontsize = 15)
# Out:
# Text(0, 0.5, 'User Rating')

# %%
fig, axes = plt.subplots(1, 3, figsize = (20, 6))
plt.suptitle('The Distribution For Numerical Data', fontsize = 15, fontweight = 'bold')
sns.boxplot(ax = axes[0], x = 'User Rating', data = book, color = '#BDD5EA')
sns.boxplot(ax = axes[1], x = 'Reviews', data = book, color = '#577399')
sns.boxplot(ax = axes[2], x = 'Price', data = book, color = '#FE5F55')
# Out:
# <AxesSubplot:xlabel='Price'>

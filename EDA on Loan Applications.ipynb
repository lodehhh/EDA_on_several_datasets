# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv('C:/Users/lode/Downloads/loan/Loan payments data.csv', index_col = 'Loan_ID')

# %%
df
# Out:
#                     loan_status  Principal  terms effective_date    due_date  \
# Loan_ID
# xqd20166231             PAIDOFF       1000     30       9/8/2016   10/7/2016
# xqd20168902             PAIDOFF       1000     30       9/8/2016   10/7/2016
# xqd20160003             PAIDOFF       1000     30       9/8/2016   10/7/2016
# xqd20160004             PAIDOFF       1000     15       9/8/2016   9/22/2016
# xqd20160005             PAIDOFF       1000     30       9/9/2016   10/8/2016
# ...                         ...        ...    ...            ...         ...
# xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016   9/26/2016
# xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016   9/26/2016
# xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016  11/10/2016
# xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
#
# ...

# %%
loan = df.copy()

# %%
loan
# Out:
#                     loan_status  Principal  terms effective_date    due_date  \
# Loan_ID
# xqd20166231             PAIDOFF       1000     30       9/8/2016   10/7/2016
# xqd20168902             PAIDOFF       1000     30       9/8/2016   10/7/2016
# xqd20160003             PAIDOFF       1000     30       9/8/2016   10/7/2016
# xqd20160004             PAIDOFF       1000     15       9/8/2016   9/22/2016
# xqd20160005             PAIDOFF       1000     30       9/9/2016   10/8/2016
# ...                         ...        ...    ...            ...         ...
# xqd20160496  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
# xqd20160497  COLLECTION_PAIDOFF       1000     15      9/12/2016   9/26/2016
# xqd20160498  COLLECTION_PAIDOFF        800     15      9/12/2016   9/26/2016
# xqd20160499  COLLECTION_PAIDOFF       1000     30      9/12/2016  11/10/2016
# xqd20160500  COLLECTION_PAIDOFF       1000     30      9/12/2016  10/11/2016
#
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, xqd20166231 to xqd20160500
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   loan_status     500 non-null    object
#  1   Principal       500 non-null    int64
#  2   terms           500 non-null    int64
#  3   effective_date  500 non-null    object
#  4   due_date        500 non-null    object
#  5   paid_off_time   400 non-null    object
#  6   past_due_days   200 non-null    float64
#  7   age             500 non-null    int64
#  8   education       500 non-null    object
#  9   Gender          500 non-null    object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 43.0+ KB

# %%
loan.shape
# Out:
# (500, 10)

# %%
loan.describe()
# Out:
#          Principal       terms  past_due_days         age
# count   500.000000  500.000000      200.00000  500.000000
# mean    943.200000   22.824000       36.01000   31.116000
# std     115.240274    8.000064       29.38088    6.084784
# min     300.000000    7.000000        1.00000   18.000000
# 25%    1000.000000   15.000000        3.00000   27.000000
# 50%    1000.000000   30.000000       37.00000   30.000000
# 75%    1000.000000   30.000000       60.00000   35.000000
# max    1000.000000   30.000000       76.00000   51.000000

# %%
loan.isnull().sum()
# Out:
# loan_status         0
# Principal           0
# terms               0
# effective_date      0
# due_date            0
# paid_off_time     100
# past_due_days     300
# age                 0
# education           0
# Gender              0
# dtype: int64

# %%
loan[['effective_date', 'due_date', 'paid_off_time']] = loan[['effective_date', 'due_date', 'paid_off_time']].apply(pd.to_datetime)

# %%
loan['due_date'].dt.year.value_counts()
# Out:
# 2016    500
# Name: due_date, dtype: int64

# %%
loan['due_date'].dt.month.value_counts()
# Out:
# 10    267
# 9     211
# 11     22
# Name: due_date, dtype: int64

# %%
loan['due_date'].dt.day.value_counts()
# Out:
# 10    133
# 25     91
# 11     69
# 26     64
# 9      37
# 13     21
# 24     17
# 27     12
# 28     10
# 12     10
# 17      7
# 8       7
# 23      6
# 18      4
# 7       4
# 19      3
# 16      3
# 22      1
# 15      1
# Name: due_date, dtype: int64

# %%
loan['paid_off_time'].dt.minute.value_counts()
# Out:
# 0.0     119
# 1.0      19
# 48.0     10
# 17.0      9
# 49.0      9
# 2.0       9
# 33.0      9
# 12.0      8
# 45.0      8
# 53.0      7
# 18.0      7
# 38.0      7
# 7.0       6
# 36.0      6
# 40.0      6
# 39.0      6
# 41.0      6
# 25.0      5
# 44.0      5
# 14.0      5
# 29.0      5
# 35.0      5
# 51.0      5
# 30.0      5
# 42.0      5
# 21.0      5
# 27.0      5
# 57.0      5
# 58.0      5
# 28.0      4
# 3.0       4
# 26.0      4
# 52.0      4
# 22.0      4
# 10.0      4
# 23.0      4
# 31.0      4
# 55.0      4
# 4.0       4
# 34.0      4
# 15.0      3
# 24.0      3
# 32.0      3
# 5.0       3
# 9.0       3
# 19.0      3
# 50.0      3
# 13.0      3
# 56.0      3
# 43.0      2
# 47.0      2
# 59.0      2
# 37.0      2
# 11.0      2
# 46.0      2
# 8.0       2
# 16.0      1
# 6.0       1
# 20.0      1
# 54.0      1
# Name: paid_off_time, dtype: int64

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, xqd20166231 to xqd20160500
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   loan_status     500 non-null    object
#  1   Principal       500 non-null    int64
#  2   terms           500 non-null    int64
#  3   effective_date  500 non-null    datetime64[ns]
#  4   due_date        500 non-null    datetime64[ns]
#  5   paid_off_time   400 non-null    datetime64[ns]
#  6   past_due_days   200 non-null    float64
#  7   age             500 non-null    int64
#  8   education       500 non-null    object
#  9   Gender          500 non-null    object
# dtypes: datetime64[ns](3), float64(1), int64(3), object(3)
# memory usage: 43.0+ KB

# %%
loan['past_due_days'].value_counts()
# Out:
# 59.0    40
# 74.0    25
# 2.0     22
# 1.0     18
# 3.0     14
# 60.0    13
# 4.0      8
# 75.0     7
# 29.0     7
# 5.0      5
# 76.0     3
# 14.0     3
# 7.0      3
# 44.0     3
# 27.0     3
# 24.0     2
# 6.0      2
# 25.0     2
# 12.0     2
# 61.0     2
# 13.0     2
# 28.0     2
# 58.0     2
# 36.0     1
# 73.0     1
# 23.0     1
# 38.0     1
# 19.0     1
# 52.0     1
# 51.0     1
# 9.0      1
# 56.0     1
# 8.0      1
# Name: past_due_days, dtype: int64

# %%
loan['past_due_days'].unique()
# Out:
# array([nan, 76., 61., 75., 60., 59., 74., 29., 44., 58., 73., 28.,  2.,
#         4., 13.,  5.,  3., 12., 27.,  1., 25., 24., 36.,  7., 14., 23.,
#         6., 38., 19., 52., 51.,  9., 56.,  8.])

# %%
loan['past_due_days'] = loan['past_due_days'].fillna(0)

# %%
loan['past_due_days'].value_counts()
# Out:
# 0.0     300
# 59.0     40
# 74.0     25
# 2.0      22
# 1.0      18
# 3.0      14
# 60.0     13
# 4.0       8
# 75.0      7
# 29.0      7
# 5.0       5
# 76.0      3
# 14.0      3
# 7.0       3
# 44.0      3
# 27.0      3
# 24.0      2
# 25.0      2
# 6.0       2
# 12.0      2
# 13.0      2
# 28.0      2
# 58.0      2
# 61.0      2
# 36.0      1
# 73.0      1
# 23.0      1
# 38.0      1
# 19.0      1
# 52.0      1
# 51.0      1
# 9.0       1
# 56.0      1
# 8.0       1
# Name: past_due_days, dtype: int64

# %%
sns.pairplot(loan, hue = 'Gender')

# %%
plt.figure(figsize = (12, 6))
sns.histplot(x = 'age', data = loan, hue = 'Gender', palette = ['#FE5F55', '#495867'], kde = True)
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Count', fontsize = 15)
plt.title('Distribution of Age by Gender', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Distribution of Age by Gender')

# %%
ax = loan['education'].value_counts().reset_index()
ax
# Out:
#                   index  education
# 0               college        220
# 1  High School or Below        209
# 2              Bechalor         67
# 3       Master or Above          4

# %%
sns.barplot(x = 'education', y = 'index', data = ax, palette = ['#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
plt.ylabel('Education', fontsize = 15)
plt.xlabel('Count', fontsize = 15)
plt.title('Total of Each Educations', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total of Each Educations')

# %%
plt.figure(figsize = (10, 6))
plt.pie(ax['education'], autopct = '%0.f%%', shadow = True, colors = ['#577399', '#BDD5EA', '#F7F7FF', '#FE5F55'])
plt.legend(labels = ['College', 'High School or Below', 'Bachelor', 'Master or Above'], bbox_to_anchor = (0, 1), fontsize = 12)
plt.title('Percentage of Each Educations', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Percentage of Each Educations')

# %%
loan
# Out:
#                     loan_status  Principal  terms effective_date   due_date  \
# Loan_ID
# xqd20166231             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20168902             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20160003             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20160004             PAIDOFF       1000     15     2016-09-08 2016-09-22
# xqd20160005             PAIDOFF       1000     30     2016-09-09 2016-10-08
# ...                         ...        ...    ...            ...        ...
# xqd20160496  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd20160497  COLLECTION_PAIDOFF       1000     15     2016-09-12 2016-09-26
# xqd20160498  COLLECTION_PAIDOFF        800     15     2016-09-12 2016-09-26
# xqd20160499  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-11-10
# xqd20160500  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
#
# ...

# %%
loan.sample(10)
# Out:
#                     loan_status  Principal  terms effective_date   due_date  \
# Loan_ID
# xqd78160129             PAIDOFF       1000     15     2016-09-11 2016-09-25
# xqd22169034             PAIDOFF       1000     30     2016-09-11 2016-10-10
# xqd20160037             PAIDOFF       1000     30     2016-09-11 2016-10-10
# xqd20160199             PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd20160308          COLLECTION       1000     30     2016-09-10 2016-10-09
# xqd20160454  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd20160145             PAIDOFF       1000     30     2016-09-11 2016-10-10
# xqd20160207             PAIDOFF       1000     30     2016-09-12 2016-11-10
# xqd20160155             PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd12160159             PAIDOFF       1000     15     2016-09-12 2016-09-26
#
#                   paid_off_time  past_due_days  age             education  \
# Loan_ID
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize = (15, 8))
plt.suptitle('Total Loan Status Per Categories', fontsize = 15, fontweight = 'bold')
ax1 = sns.countplot(ax = axes[0], x = 'loan_status', data = loan, hue = 'Gender', palette = ['#577399', '#BDD5EA'])
ax2 = sns.countplot(ax = axes[1], x = 'loan_status', data = loan, hue = 'education', palette = ['#495867', '#577399', '#BDD5EA', '#FE5F55'])
ax1.tick_params('x', labelrotation = 20)
ax2.tick_params('x', labelrotation = 20)

# %%
loan.sample(10)
# Out:
#                     loan_status  Principal  terms effective_date   due_date  \
# Loan_ID
# xqd20160120             PAIDOFF        800     15     2016-09-11 2016-09-25
# xqd20160440  COLLECTION_PAIDOFF       1000     30     2016-09-11 2016-11-09
# xqd20160312          COLLECTION        800     15     2016-09-10 2016-09-24
# xqd20160222             PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd20160020             PAIDOFF        800     30     2016-09-10 2016-10-09
# xqd20160165             PAIDOFF       1000     15     2016-09-12 2016-09-26
# xqd20160116             PAIDOFF       1000     15     2016-09-11 2016-09-25
# xqd20160422  COLLECTION_PAIDOFF       1000     30     2016-09-11 2016-10-10
# xqd20160301          COLLECTION       1000     15     2016-09-09 2016-09-23
# xqd20160171             PAIDOFF       1000     15     2016-09-12 2016-09-26
#
#                   paid_off_time  past_due_days  age             education  \
# Loan_ID
# ...

# %%
loan['terms'].unique()
# Out:
# array([30, 15,  7], dtype=int64)

# %%
loan['Terms'] = loan['terms'].replace({7 : 'short', 15 : 'middle', 30 : 'long'})

# %%
plt.figure(figsize = (12, 6))
plt.pie(x = loan['Terms'].value_counts(), data = loan, autopct = '%0.f%%', shadow = True, colors = ['#577399', '#BDD5EA', '#F7F7FF'])
plt.legend(labels = ['long', 'middle', 'short'], bbox_to_anchor = (0,1), fontsize = 15)
plt.title('Percentage of Each Terms Levels', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Percentage of Each Terms Levels')

# %%
fig, axes = plt.subplots(1, 2, figsize = (15, 8))
plt.suptitle('Total Terms Level Per Categories', fontsize = 15, fontweight = 'bold')
ax1 = sns.countplot(ax = axes[0], x = 'Terms', data = loan, hue = 'Gender', palette = ['#577399', '#BDD5EA'])
ax2 = sns.countplot(ax = axes[1], x = 'Terms', data = loan, hue = 'education', palette = ['#495867', '#577399', '#BDD5EA', '#FE5F55'])

# %%
loan['age'].value_counts().sort_index()
# Out:
# 18     1
# 19     2
# 20     4
# 21     7
# 22     8
# 23    10
# 24    23
# 25    20
# 26    46
# 27    38
# 28    32
# 29    42
# 30    37
# 31    22
# 32    20
# 33    30
# 34    25
# 35    26
# 36    14
# 37    19
# 38    19
# 39    10
# 40     8
# 41     5
# 42     4
# 43     5
# 44     4
# 45     5
# 46     5
# 47     3
# 49     1
# 50     4
# 51     1
# Name: age, dtype: int64

# %%
plt.figure(figsize = (10, 6))
sns.countplot(x = 'terms', data = loan, hue = 'loan_status', palette = ['#495867', '#577399', '#BDD5EA'])
plt.legend(loc = 'upper left')
plt.xlabel('terms', fontsize = 15)
plt.ylabel('count', fontsize = 15)
plt.title('Total of Terms for Each Loan Status', fontsize = 15, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Total of Terms for Each Loan Status')

# %%
sns.catplot(x = 'Principal', hue = 'loan_status', col = 'Gender', data = loan, kind = 'count',
            palette = ['#495867', '#577399', '#BDD5EA'],
           height = 6, aspect = 1)

# %%
sns.violinplot(x = 'Principal', y = 'terms', hue = 'Gender', data = loan, split = True, inner = 'quart', palette = ['#BDD5EA', '#FE5F55'])
# Out:
# <AxesSubplot:xlabel='Principal', ylabel='terms'>

# %%
loan['Principal'].unique()
# Out:
# array([1000,  300,  800,  900,  700,  500], dtype=int64)

# %%
sns.lmplot(x = 'age', y = 'Principal', hue = 'Gender', data = loan, truncate = True, height = 5, palette = ['#FE5F55', '#BDD5EA'])
plt.xlabel('Age', fontsize = 15)
plt.ylabel('Principal', fontsize = 15)
plt.title('The Distribution of Loan Applications Based on Age and Gender', fontsize = 14, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'The Distribution of Loan Applications Based on Age and Gender')

# %%
loan.shape[0]
# Out:
# 500

# %%
loan['past_due_days'].isnull().sum()
# Out:
# 0

# %%
loan[loan['past_due_days'] == 0].shape[0]
# Out:
# 300

# %%
percent_paid = ((loan.shape[0] - loan[loan['past_due_days'] == 0].shape[0]) / (loan.shape[0])) * 100
print(percent_paid, '% of people paid after time')
# Out:
# 40.0 % of people paid after time

# %%
labels = ['After Due Date', 'Before Due Date']
size = [percent_paid, 100 - percent_paid]
explode = (0, 0.1)

# %%
fig1, ax1 = plt.subplots(figsize = (8, 4))
plt.suptitle('Percentage of People Paid Before or After Due Date', fontsize = 15, fontweight = 'bold')
plt.pie(x = size, explode = explode, autopct = '%1.1f%%', shadow = True, startangle = 90, colors = ['#577399', '#BDD5EA'])
ax1.axis('equal')
plt.legend(labels, bbox_to_anchor = (0.2, 1))

# %%
sns.boxplot(x = 'education', y = 'Principal', data = loan, palette = ['#495867', '#577399', '#BDD5EA', '#FE5F55'])
# Out:
# <AxesSubplot:xlabel='education', ylabel='Principal'>

# %%
loan
# Out:
#                     loan_status  Principal  terms effective_date   due_date  \
# Loan_ID
# xqd20166231             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20168902             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20160003             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20160004             PAIDOFF       1000     15     2016-09-08 2016-09-22
# xqd20160005             PAIDOFF       1000     30     2016-09-09 2016-10-08
# ...                         ...        ...    ...            ...        ...
# xqd20160496  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd20160497  COLLECTION_PAIDOFF       1000     15     2016-09-12 2016-09-26
# xqd20160498  COLLECTION_PAIDOFF        800     15     2016-09-12 2016-09-26
# xqd20160499  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-11-10
# xqd20160500  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
#
# ...

# %%
fig = plt.figure(figsize=(15,5))
ax = sns.countplot(x="effective_date", hue="loan_status", data=loan ,palette='pastel' ,edgecolor=sns.color_palette("dark", 3))
ax.set_title('Loan date')
ax.tick_params('x', labelrotation = 45)
ax.legend(loc='upper right')
for t in ax.patches:
    if (np.isnan(float(t.get_height()))):
        ax.annotate(0, (t.get_x(), 0))
    else:
        ax.annotate(str(format(int(t.get_height()), ',d')), (t.get_x(), t.get_height()*1.01))
plt.show();

# %%
loan
# Out:
#                     loan_status  Principal  terms effective_date   due_date  \
# Loan_ID
# xqd20166231             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20168902             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20160003             PAIDOFF       1000     30     2016-09-08 2016-10-07
# xqd20160004             PAIDOFF       1000     15     2016-09-08 2016-09-22
# xqd20160005             PAIDOFF       1000     30     2016-09-09 2016-10-08
# ...                         ...        ...    ...            ...        ...
# xqd20160496  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
# xqd20160497  COLLECTION_PAIDOFF       1000     15     2016-09-12 2016-09-26
# xqd20160498  COLLECTION_PAIDOFF        800     15     2016-09-12 2016-09-26
# xqd20160499  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-11-10
# xqd20160500  COLLECTION_PAIDOFF       1000     30     2016-09-12 2016-10-11
#
# ...
